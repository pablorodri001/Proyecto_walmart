# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# %%
df=pd.read_csv('../data/processed/Datos_Fecha_Dividida.csv')

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Store  Dept        Date  Weekly_Sales  IsHoliday  \
# 0             0           0      1     1  2010-02-05      24924.50      False
# 1             1           1      1     1  2010-02-12      46039.49       True
# 2             2           2      1     1  2010-02-19      41595.55      False
# 3             3           3      1     1  2010-02-26      19403.54      False
# 4             4           4      1     1  2010-03-05      21827.90      False
#
#    Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0        42.31       2.572        NaN        NaN        NaN        NaN
# 1        38.51       2.548        NaN        NaN        NaN        NaN
# 2        39.93       2.514        NaN        NaN        NaN        NaN
# 3        46.63       2.561        NaN        NaN        NaN        NaN
# 4        46.50       2.625        NaN        NaN        NaN        NaN
#
#    MarkDown5         CPI  Unemployment Type    Size  Month  Year
# 0        NaN  211.096358         8.106    A  151315      2  2010
# 1        NaN  211.242170         8.106    A  151315      2  2010
# 2        NaN  211.289143         8.106    A  151315      2  2010
# 3        NaN  211.319643         8.106    A  151315      2  2010
# 4        NaN  211.350143         8.106    A  151315      3  2010

# %%
X=df.drop(['Weekly_Sales','Date'],axis=1,errors='ignore')
y=df['Weekly_Sales']
